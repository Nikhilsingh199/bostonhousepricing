# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Lets load the Boston House Pricing Dataset

# %%
boston = pd.read_csv("D:\pycharm\HousingData.csv")

# %%
boston.keys()
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# ## Preparing the Dataset

# %%
dataset =boston

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
dataset.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
dataset =dataset.dropna(axis=0)

# %%
dataset.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
## EDA
## Correlation in any regression problem
dataset.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.188075  0.391552 -0.051970  0.416160 -0.227170  0.341311
# ZN      -0.188075  1.000000 -0.521256 -0.033357 -0.515660  0.343210 -0.568174
# INDUS    0.391552 -0.521256  1.000000  0.049820  0.762737 -0.403068  0.642387
# CHAS    -0.051970 -0.033357  0.049820  1.000000  0.076661  0.095308  0.072644
# NOX      0.416160 -0.515660  0.762737  0.076661  1.000000 -0.316563  0.732540
# RM      -0.227170  0.343210 -0.403068  0.095308 -0.316563  1.000000 -0.248670
# AGE      0.341311 -0.568174  0.642387  0.072644  0.732540 -0.248670  1.000000
# DIS     -0.365052  0.645359 -0.696569 -0.095037 -0.768137  0.218713 -0.753547
# RAD      0.608667 -0.298773  0.591944  0.014102  0.628170 -0.236057  0.443585
# TAX      0.560841 -0.305768  0.734204 -0.026513  0.679824 -0.320561  0.504472
# PTRATIO  0.265428 -0.422164  0.395691 -0.104995  0.210216 -0.390686  0.264968
# ...

# %%
import seaborn as sns
sns.pairplot(dataset)

# %%
plt.scatter(dataset['CRIM'],dataset['MEDV'])
plt.xlabel("crime")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
import seaborn as sns
sns.regplot(x="RM",y="MEDV",data=dataset)
# Out:
# <AxesSubplot:xlabel='RM', ylabel='MEDV'>

# %%
sns.regplot(x="LSTAT",y="MEDV",data=dataset)
# Out:
# <AxesSubplot:xlabel='LSTAT', ylabel='MEDV'>

# %%
sns.regplot(x="CHAS",y="MEDV",data=dataset)
# Out:
# <AxesSubplot:xlabel='CHAS', ylabel='MEDV'>

# %%
sns.regplot(x="PTRATIO",y="MEDV",data=dataset)
# Out:
# <AxesSubplot:xlabel='PTRATIO', ylabel='MEDV'>

# %%
## Independent and dependent features 

X =dataset.iloc[:,:-1]
y =dataset.iloc[:,-1]

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 5      28.7
#        ...
# 499    17.5
# 500    16.8
# 502    20.6
# 503    23.9
# 504    22.0
# Name: MEDV, Length: 394, dtype: float64

# %%
# train test split

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X,y,test_size =0.3,random_state=42)

# %%
X_train
# Out:
#          CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 21    0.85204  0.0   8.14   0.0  0.538  5.965  89.2  4.0123    4  307
# 456   4.66883  0.0  18.10   0.0  0.713  5.976  87.9  2.5806   24  666
# 28    0.77299  0.0   8.14   0.0  0.538  6.495  94.4  4.4547    4  307
# 156   2.44668  0.0  19.58   0.0  0.871  5.272  94.0  1.7364    5  403
# 445  10.67180  0.0  18.10   0.0  0.740  6.459  94.8  1.9879   24  666
# ..        ...  ...    ...   ...    ...    ...   ...     ...  ...  ...
# 84    0.05059  0.0   4.49   0.0  0.449  6.389  48.0  4.7794    3  247
# 128   0.32543  0.0  21.89   0.0  0.624  6.431  98.8  1.8125    4  437
# 345   0.03113  0.0   4.39   0.0  0.442  6.014  48.5  8.0136    3  352
# 448   9.32909  0.0  18.10   0.0  0.713  6.185  98.7  2.2616   24  666
# 122   0.09299  0.0  25.65   0.0  0.581  5.961  92.9  2.0869    2  188
#
#      PTRATIO       B  LSTAT
# 21      21.0  392.53  13.83
# 456     20.2   10.48  19.01
# 28      21.0  387.94  12.80
# ...

# %%
## Standard scaling 
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()

X_train =scaler.fit_transform(X_train)
X_test =scaler.transform(X_test)

# %% [markdown]
# ## mODDEL tRAINING

# %%
from sklearn.linear_model import LinearRegression

# %%
regression =LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(regression.coef_)
# Out:
# [-1.16422484  1.06108499  0.39032387  0.29209079 -1.99660097  2.919107
#  -0.56678274 -2.98589329  2.41887408 -2.87948075 -1.92242361  0.87551786
#  -2.71551439]

# %%
print(regression.intercept_)
# Out:
# 21.872363636363634

# %%
regression.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
## Prediction with test data
reg_pred =regression.predict(X_test)

# %%
reg_pred
# Out:
# array([29.48758967, 16.89843072, 21.88395113, 30.03140416, 18.33998157,
#        34.41717332, 22.29567579, 30.18541478, 32.68800811, 15.15148614,
#        22.00937236, 40.89756783, 21.39760824, 16.631487  , 18.56021823,
#        20.16135634, 17.03230083, 15.23458095, 22.21007405, 14.03864948,
#        18.38308584, 20.31978106, 16.70540425, 29.04732153, 25.84896274,
#        16.21750987, 26.91521769, 31.48625718, 23.80195772, 26.88649048,
#        40.79205858, 17.93939578, 21.74000234, 17.0218407 , 17.45215081,
#        20.87478891, 22.15708989, 21.38558618, 23.05850448, 21.06608939,
#        27.72449001, 34.81400202, 21.78651421, 30.44288708, 34.59722541,
#        19.75813031, 24.68728038, 10.22457273, 19.81849411, 25.15817576,
#        21.82205121, 25.58520471, 14.76531893, 18.31754995, 18.17045495,
#        23.96198129, 43.37418034, 22.39050206, 15.68056608, 23.22677962,
#        20.98939499, 21.55059106, 14.59407927, 28.87042011, -3.45096729,
# ...

# %%
## plot a scatter plot for prediction

plt.scatter(y_test,reg_pred)

# %%
## Prediction with redifuals
residuals =y_test-reg_pred
sns.displot(residuals,kind="kde")
## get thsi as normal distribution

# %%
## Scatter plot with predictions and residuals

plt.scatter(reg_pred,residuals)
## should be uniform distibution not in any shape

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 3.4558210072479936
# 28.870771928253443
# 5.373152885248422

# %% [markdown]
# ## Adjusted r squareand r squared
#
# Formula for R^2 = 1- SSR/SST
# R^2 = coefficient of determination SSR = sum of squares of residuals SST = total sum of square
#
#
# ## Formula for adjusted r squared
# R2 = 1-[(1.R2)*(n-1)/(n-k-1)]
#
# where :
# R2: The R2 of the model n: The number of observations k: The number of predictor variables.

# %%
# adjusted r2 will alwways be less than r2
from sklearn.metrics import r2_score
score = r2_score(y_test,reg_pred)
print("R squared",score)
# Out:
# R squared 0.6905175764205996

# %%
# display adjusted r squared
1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.6522007049298166

# %% [markdown]
# ## New data Prediction
# # make the data in the correct shape
# # standardize the values
# # Predict the result

# %% [markdown]
# ## Pickling The mODEL file for Deployment

# %%
import pickle

# %%
pickle.dump(regression,open('regmodel.pkl','wb'))

# %%
pickled_model =pickle.load(open('regmodel.pkl','rb'))

# %%
pickled_model.predict([[0.51, 0.82, 0.15, 0.33, 0.72, 0.65, 0.94, 0.44, 0.23, 0.78, 0.61, 0.90,0.67]])
# Out:
# array([17.02317431])

# %%
import os
print(os.getcwd())  # Shows the current directory
# Out:
# C:\Users\Lenovo
